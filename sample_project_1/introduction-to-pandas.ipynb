# %%
import pandas as pd

# %%
# 2 main data types (series which is 1D and dataframe which is 2D)

series = pd.Series(["BMW", "Volkswagen", "Porsche"])

# %%
series
# Out:
# 0           BMW
# 1    Volkswagen
# 2       Porsche
# dtype: object

# %%
colors = pd.Series(["Red", "Yellow", "Blue"])
colors
# Out:
# 0       Red
# 1    Yellow
# 2      Blue
# dtype: object

# %%
car_data = pd.DataFrame({"Car Make": series, "Color": colors})
car_data
# Out:
#      Car Make   Color
# 0         BMW     Red
# 1  Volkswagen  Yellow
# 2     Porsche    Blue

# %%
#Import data into dataframe
external = pd.read_csv("car-sales.csv")
car_data = pd.DataFrame(external)

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#x-axis = 0
#y-axis = 1

# %%
#Export data
#Adding index = False stops the auto index column from veing exported
car_data.to_csv("exported-car-sales.csv", index=False)

# %%
export_car_sales = pd.read_csv("exported-car-sales.csv")

# %%
export_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00
